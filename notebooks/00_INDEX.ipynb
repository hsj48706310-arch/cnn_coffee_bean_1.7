# %% [markdown]
# # Notebook Index\n\n아래 순서대로 실행하면 데이터 준비 → 학습 → 평가 → 추론 흐름을 따라갈 수 있습니다.\n

# %% [markdown]
# - notebooks/app/streamlit_app.ipynb\n

# %% [markdown]
# - notebooks/scripts/download_extra.ipynb\n

# %% [markdown]
# - notebooks/scripts/download_kaggle.ipynb\n

# %% [markdown]
# - notebooks/scripts/dump_test_metrics.ipynb\n

# %% [markdown]
# - notebooks/scripts/fix_dup.ipynb\n

# %% [markdown]
# - notebooks/scripts/make_splits.ipynb\n

# %% [markdown]
# - notebooks/src/dataset.ipynb\n

# %% [markdown]
# - notebooks/src/evaluate.ipynb\n

# %% [markdown]
# - notebooks/src/export_onnx.ipynb\n

# %% [markdown]
# - notebooks/src/infer.ipynb\n

# %% [markdown]
# - notebooks/src/losses.ipynb\n

# %% [markdown]
# - notebooks/src/model.ipynb\n

# %% [markdown]
# - notebooks/src/train.ipynb\n

# %% [markdown]
# - notebooks/src/utils/config.ipynb\n

# %% [markdown]
# - notebooks/src/utils/logger.ipynb\n

# %% [markdown]
# - notebooks/src/utils/seed.ipynb\n

# %% [markdown]
# - notebooks/src/webcam_demo.ipynb\n
